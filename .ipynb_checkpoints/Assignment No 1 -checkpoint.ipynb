# %% [markdown]
# # Question No 1

# %%
Name = "Abdul Hammad"
Age = 17
Course = "Ai and Data Science"
Institute = "Saylani Mass IT Training"
print("Name :" , Name)
print("Age :" , Age)
print("Course :" , Course)
print("Institute :" , Institute)
# Out:
# Name : Abdul Hammad
# Age : 17
# Course : Ai and Data Science
# Institute : Saylani Mass IT Training

# %% [markdown]
# # Question NO 2

# %%
Emp_Name = "Abdul Hammad"
Department = "Data Science"
Experience = "4 Years"
Salary = 65000
print("Emp_Name :" , Emp_Name)
print("Department :" , Department)
print("Experience :" , Experience)
print("Salary :" , Salary)
# Out:
# Emp_Name : Abdul Hammad
# Department : Data Science
# Experience : 4 Years
# Salary : 65000

# %% [markdown]
# # Question No 3

# %%
Product_Name = "Laptop"
Price = 85000
Quantity = 35
print("Product_Name :" , Product_Name)
print("Price :" , Price)
print("Quantity :" , Quantity)
# Out:
# Product_Name : Laptop
# Price : 85000
# Quantity : 35

# %% [markdown]
# # Question No 4

# %%
Your_name = input("Enter your name")
Your_age = input("Enter your age")
Your_city = input("Enter your city")
Your_course = input("Enter your course")
print(f"Name : {Your_name} , Age : {Your_age} , City : {Your_city} , Course : {Your_course}")
# Out:
# Enter your name Abdul Hammad
# Enter your age 19
# Enter your city Karachi
# Enter your course AI and DS
# Name : Abdul Hammad , Age : 19 , City : Karachi , Course : AI and DS

# %% [markdown]
# # Question No 5

# %%
User_name = input("Enter your user name")
print(f"Welcome {User_name}")
# Out:
# Enter your user name hammad980
# Welcome hammad980

# %% [markdown]
# # Question No 6

# %%
Name=input("What is your name")
Age=input("What is your age")
City=input("What is your city")
Course=input("What is your course")
print(f"Your name is : {Name} , Your age is : {Age} , Your city is : {City} and Your course is : {Course}")
# Out:
# What is your name Abdul Hammad
# What is your age 19
# What is your city Karachi
# What is your course AI and DS
# Your name is : Abdul Hammad , Your age is : 19 , Your city is : Karachi and Your course is : AI and DS

# %% [markdown]
# # Question No 7

# %%
Birth_year = int(input("Enter Your Brith Date:"))
Current_year = int(input("Current Year:"))
Your_age = Current_year - Birth_year 
print(Your_age)
# Out:
# Enter Your Brith Date: 2007
# Current Year: 2026
# 19

# %% [markdown]
# # Question No 8

# %%
Price_of_Product = float(input("Enter your Product Price:"))
Quantity_of_Product = float(input("Enter your Quantity of product:"))
Total_Bill = Price_of_Product * Quantity_of_Product
print(Total_Bill)
# Out:
# Enter your Product Price: 3000
# Enter your Quantity of product: 57
# 171000.0

# %% [markdown]
# # Question No 9

# %%
Temprature_in_Celsius = float(input("Your temprature in celsius:"))
Celsius_to_Fahrenheit = ( Temprature_in_Celsius * 9/5) + 32 
print(Celsius_to_Fahrenheit)
# Out:
# Your temprature in celsius: 46
# 114.8

# %% [markdown]
# # Question 10

# %%
Marks_in_MATHEMATICS = float(input("Marks in Mathematics"))
Marks_in_STATISTICS = float(input("Marks in Statistics:"))
Marks_in_ECNOMICS = float(input("Marks in Economics:"))
Total_Marks = Marks_in_MATHEMATICS + Marks_in_STATISTICS + Marks_in_ECNOMICS
Averages = Total_Marks/3
print(Total_Marks)
print(Averages)
# Out:
# Marks in Mathematics 78
# Marks in Statistics: 92
# Marks in Economics: 86
# 256.0
# 85.33333333333333

# %% [markdown]
# # Question No 11

# %%
Your_First_Name = input('Enter Your First Name:')
Your_Second_Name = input('Enter Your Second Name:')
Full_Name_Generator = Your_First_Name + Your_Second_Name
print(f"Your Full Name is : {Full_Name_Generator}")
# Out:
# Enter Your First Name: Abdul
# Enter Your Second Name: Hammad
# Your Full Name is : AbdulHammad

# %% [markdown]
# # Question NO 12

# %%
Your_first_name = input('Enter your first name')
Your_second_name = input('Enter your second name')
clean_first = Your_first_name.strip().lower()
clean_second = Your_second_name.strip().lower()
domain = '@gmail.com'
email_address = f"{clean_first}.{clean_second}{domain}"
print("\Generated Email Address:")
print(email_address)
# Out:
# Enter your first name Abdul
# Enter your second name Hammad
# \Generated Email Address:
# abdul.hammad@gmail.com

# %% [markdown]
# # Question No 13

# %%
house=int(input("Enter your house number"))
street_name=input("Enter your street name")
city_name=input("Enter your city name")
print(f"Full adress is {house},{street_name},{city_name}")
# Out:
# Enter your house number 74
# Enter your street name Main Street
# Enter your city name Karachi
# Full adress is 74,Main Street,Karachi

# %% [markdown]
# # Question No 14

# %%
symbol = input("Enter a symbol: ")
number = int(input("Enter a number: "))

print(symbol * number)
# Out:
# Enter a symbol:  $
# Enter a number:  5
# $$$$$

# %% [markdown]
# # Question No 15

# %%
num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, x, /): ")
num2 = float(input("Enter second number: "))

if operator == "+":
    result = num1 + num2

elif operator == "-":
    result = num1 - num2

elif operator == "x":
    result = num1 * num2

elif operator == "/":
    result = num1 / num2

else:
    result = "Invalid operator"

print("Result:", result)
# Out:
# Enter first number:  60
# Enter operator (+, -, x, /):  /
# Enter second number:  3
# Result: 20.0

# %% [markdown]
# # Question No 16

# %%
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

area = length * width
perimeter = 5 * (length + width)

print(f"Area:      {area:.5f}")
print(f"Perimeter: {perimeter:.5f}")
# Out:
# Enter the length of the rectangle:  5
# Enter the width of the rectangle:  2
# Area:      10.00000
# Perimeter: 35.00000

# %% [markdown]
# # Question No 17

# %%
radius = float(input("Enter the radius of the circle: "))
pi = 3.1423
area = pi * (radius **2)
circumference = 2 * pi * radius

print(f"Radius: {radius}")
print(f"Area: {area}")
print(f"Circumference: {circumference}")
# Out:
# Enter the radius of the circle:  8
# Radius: 8.0
# Area: 201.1072
# Circumference: 50.2768

# %% [markdown]
# # Question No 18

# %%
principal = float(input("Enter the principal amount : "))
rate = float(input("Enter the annual interest rate : "))
time = float(input("Enter the time period (in years): "))

simple_interest = (principal * rate * time) / 100


print(f"\nThe calculated Simple Interest is: {simple_interest:.2f}")
# Out:
# Enter the principal amount :  4500
# Enter the annual interest rate :  0.15
# Enter the time period (in years):  6
# The calculated Simple Interest is: 40.50

# %% [markdown]
# # Question No 19

# %%
unit_price = 40 
quantity = 5 
total_price = unit_price * quantity
discount = total_price * 0.10 #discount
final_price = total_price - discount
print(f"Total price: {total_price}")
print(f"final price : {final_price}")
# Out:
# Total price: 200
# final price : 180.0

# %% [markdown]
# # Question No 20

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are 18+ ")
else:
    print("You are under 18.")
# Out:
# Enter your age:  19
# You are 18+

# %% [markdown]
# # Question No 21

# %%
marks = int(input("Enter your marks: "))

if marks >= 50:
    print("You Passed!")
else:
    print("You Failed.")
# Out:
# Enter your marks:  70
# You Passed!

# %% [markdown]
# # Question No 22

# %%
age = 19
has_license = True
age >= 18 and has_license
# Out:
# True

# %% [markdown]
# # Question No 23

# %%
marks = float(input("Enter your marks: "))
age = int(input("Enter your age: "))

if marks >= 50 and age >= 18:
    print("Admission allowed.")
else:
    print("Admission not allowed.")
# Out:
# Enter your marks:  78
# Enter your age:  19
# Admission allowed.

# %% [markdown]
# # Question No 24

# %%
purchase_amount = 7500
is_member = False

if purchase_amount >= 5000 or is_member == True:
    print("Eligible for discount")
else:
    print("Not eligible for discount")
# Out:
# Eligible for discount

# %% [markdown]
# # Question No 25

# %%
correct_username = "ahsan"
correct_password = "password748"

entered_username = input("Enter your username: ")
entered_password = input("Enter your password: ")

if entered_username == correct_username and entered_password == correct_password:
    print("Login successful! Welcome.")
else:
    print("Login failed. Invalid username or password.")
# Out:
# Enter your username:  ahsan
# Enter your password:  password748
# Login successful! Welcome.

# %% [markdown]
# # Question No 26

# %%
word = input("Enter a word: ")
character = input("Enter a character to check: ")

if character in word:
  print("The character is in the word.")

if character not in word:
  print("The character is not in the word.")
# Out:
# Enter a word:  strong
# Enter a character to check:  o
# The character is in the word.

# %% [markdown]
# # Question No 27

# %%
email = input("Enter your email: ")
if "@" in email:
    print("Email looks valid (contains @).")
else:
    print("Invalid email (@ missing).")
# Out:
# Enter your email:  shaarjeel857@gmail.com
# Email looks valid (contains @).

# %% [markdown]
# # Question No 28

# %%
sentence = input("Enter a sentence: ")

if "python" in sentence:
  print("Yes, the word 'python' exists in the sentence.")
else:
  print("No, the word 'python' exists not in the sentence.")
# Out:
# Enter a sentence:  I love python
# Yes, the word 'python' exists in the sentence.
