# %% [markdown]
# # Question 01

# %%
Name = "Mohsin Raza"
Age = 20
Course = "Ai and Data Science"
Institute_Name = "Saylani Mass IT Training"
print("Name :" , Name)
print("Age :" , Age)
print("Course :" , Course)
print("Institute_Name :" , Institute_Name)
# Out:
# Name : Mohsin Raza
# Age : 20
# Course : Ai and Data Science
# Institute_Name : Saylani Mass IT Training

# %% [markdown]
# # Question 02

# %%
Emp_Name = "Mohsin Raza"
Department = "Data Science"
Experience = "2 Years"
Salary = 65000
print("Emp_Name :" , Emp_Name)
print("Department :" , Department)
print("Experience :" , Experience)
print("Salary :" , Salary)
# Out:
# Emp_Name : Mohsin Raza
# Department : Data Science
# Experience : 2 Years
# Salary : 65000

# %% [markdown]
# # Question 03

# %%
Product_Name = "laptop"
Price = 45000
Quantity = 75
print("Product_Name :" , Product_Name)
print("Price :" , Price)
print("Quantity :" , Quantity)
# Out:
# Product_Name : laptop
# Price : 45000
# Quantity : 75

# %% [markdown]
# # Question 04

# %%
Your_name = input("Enter your name")
Your_age = input("Enter your age")
Your_city = input("Enter your city")
Your_course = input("Enter your course")
print(f"Name : {Your_name} , Age : {Your_age} , city : {Your_city} , course : {Your_course}")
# Out:
# Enter your name mohsin raza
# Enter your age 20
# Enter your city karachi
# Enter your course ai
# Name : mohsin raza , Age : 20 , city : karachi , course : ai

# %% [markdown]
# # Question 05

# %%
user_name = input("enter your user name")
print(f"welcome {user_name}")
# Out:
# enter your user name mohsin123
# welcome mohsin123

# %% [markdown]
# # Question 06

# %%
Your_name=input("what is your name")
Your_age=input("what is your age")
Your_city=input("what is your city")
Your_course=input("what is your course")
print(f"your name is {Your_name} , your age is {Your_age} ,your city is {Your_city} and your course is {Your_course}")
# Out:
# what is your name Mohsin
# what is your age 20
# what is your city karachi
# what is your course AI and data science
# your name is Mohsin , your age is 20 ,your city is karachi and your course is AI and data science

# %% [markdown]
#  # Question 07

# %%
Your_BirthYear = int(input("your brith date:"))
Current_Year = int(input("current year:"))
Your_age = Current_Year - Your_BirthYear 
print(Your_age)
# Out:
# your brith date: 2005
# current year: 2026
# 21

# %% [markdown]
# # Question 08

# %%
Price_of_Product = float(input("Enter your Product Price:"))
Quantity_of_Product = float(input("Enter your Quantity of product:"))
Total_Bill = Price_of_Product * Quantity_of_Product
print(Total_Bill)
# Out:
# Enter your Product Price: 200
# Enter your Quantity of product: 10
# 2000.0

# %% [markdown]
# # Question 09

# %%
Temprature_in_Celsius = float(input("Your temprature in celsius:"))
Celsius_To_Fahrenheit = ( Temprature_in_Celsius * 9/5) + 32 
print(Celsius_To_Fahrenheit)
# Out:
# Your temprature in celsius: 20
# 68.0

# %% [markdown]
# # Question 10

# %%
Marks_in_statistics_405 = float(input("marks in statistics 405:"))
Marks_in_statistics_411 = float(input("marks in statistics 411:"))
Marks_in_Economics = float(input("marks in economics:"))
total_Marks = Marks_in_statistics_405 + Marks_in_statistics_411 + Marks_in_Economics
Averages = total_Marks/3
print(total_Marks)
print(Averages)
# Out:
# marks in statistics 405: 73
# marks in statistics 411: 75
# marks in economics: 81
# 229.0
# 76.33333333333333

# %% [markdown]
# # Question 11

# %%
Your_first_name = input('Enter your first name')
Your_second_name = input('Enter your second name')
Full_Name_generator = Your_first_name + Your_second_name
print(f"your Full Name is {Full_Name_generator}")
# Out:
# Enter your first name Mohsin
# Enter your second name Raza
# your Full Name is Mohsin Raza

# %% [markdown]
# # Question 12

# %%
Your_first_name = input('Enter your first name')
Your_second_name = input('Enter your second name')
cLean_first = Your_first_name.strip().lower()
clean_second = Your_second_name.strip().lower()
domain = '@gmail.com'
email_address = f"{clean_first}.{clean_second}{domain}"
print("\Generated Email Address:")
print(email_address)
# Out:
# Enter your first name mohsin
# Enter your second name Raza
# \Generated Email Address:
# mohsin.raza@gmail.com

# %% [markdown]
# # Question 13

# %%
house=int(input("Enter your house number"))
street_name=input("Enter your street name")
city_name=input("Enter your city name")
print(f"Full adress is {house},{street_name},{city_name}")
# Out:
# Enter your house number 125
# Enter your street name gali
# Enter your city name karachi
# Full adress is 125,gali,karachi

# %% [markdown]
# # Question 14

# %%
symbol = input("Enter a symbol: ")
number = int(input("Enter a number: "))

print(symbol * number)
# Out:
# Enter a symbol:  *
# Enter a number:  2
# **

# %% [markdown]
# # Question 15

# %%
num1 = float(input("Enter first number: "))
operator = input("Enter operator (+, -, x, /): ")
num2 = float(input("Enter second number: "))

if operator == "+":
    result = num1 + num2

elif operator == "-":
    result = num1 - num2

elif operator == "x":
    result = num1 * num2

elif operator == "/":
    result = num1 / num2

else:
    result = "Invalid operator"

print("Result:", result)
# Out:
# Enter first number:  2
# Enter operator (+, -, x, /):  x
# Enter second number:  2
# Result: 4.0

# %% [markdown]
# # Question 16

# %%
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

area = length * width
perimeter = 2 * (length + width)

print(f"Area:      {area:.2f}")
print(f"Perimeter: {perimeter:.2f}")
# Out:
# Enter the length of the rectangle:  5
# Enter the width of the rectangle:  2
# --- Results ---
# Area:      10.00
# Perimeter: 14.00

# %% [markdown]
# # Question 17

# %%
radius = float(input("Enter the radius of the circle: "))
pi = 3.1423
area = pi * (radius **2)
circumference = 2 * pi * radius

print(f"Radius: {radius}")
print(f"Area: {area}")
print(f"Circumference: {circumference}")
# Out:
# Enter the radius of the circle:  5
# Radius: 5.0
# Area: 78.5575
# Circumference: 31.423000000000002

# %% [markdown]
# # Question 18

# %%
principal = float(input("Enter the principal amount : "))
rate = float(input("Enter the annual interest rate : "))
time = float(input("Enter the time period (in years): "))

simple_interest = (principal * rate * time) / 100


print(f"\nThe calculated Simple Interest is: {simple_interest:.2f}")
# Out:
# Enter the principal amount :  1000
# Enter the annual interest rate :  0.15
# Enter the time period (in years):  2
# The calculated Simple Interest is: 3.00

# %% [markdown]
# # Question 19

# %%
unit_price = 50 
quantity = 10 
total_price = unit_price * quantity
discount = total_price * 0.10 #discount
final_price = total_price - discount
print(f"Total price: {total_price}")
print(f"final price : {final_price}")
# Out:
# Total price: 500
# final price : 450.0

# %% [markdown]
# # Question 20

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("You are 18+ ")
else:
    print("You are under 18.")
# Out:
# Enter your age:  21
# You are 18+

# %% [markdown]
# # Question 21

# %%
marks = int(input("Enter your marks: "))

if marks >= 50:
    print("You Passed!")
else:
    print("You Failed.")
# Out:
# Enter your marks:  71
# You Passed!

# %% [markdown]
# # Question 22

# %%
age = 20
has_license =True
age >= 18 and has_license
# Out:
# True

# %% [markdown]
# # Question 23

# %%
marks = float(input("Enter your marks: "))
age = int(input("Enter your age: "))

if marks >= 50 and age >= 18:
    print("Admission allowed.")
else:
    print("Admission not allowed.")
# Out:
# Enter your marks:  85
# Enter your age:  21
# Admission allowed.

# %% [markdown]
# # Question 24

# %%
purchase_amount = 5500
is_member = False

if purchase_amount >= 5000 or is_member == True:
    print("Eligible for discount")
else:
    print("Not eligible for discount")
# Out:
# Eligible for discount

# %% [markdown]
# # Question 25

# %%
correct_username = "admin"
correct_password = "password123"

entered_username = input("Enter your username: ")
entered_password = input("Enter your password: ")

if entered_username == correct_username and entered_password == correct_password:
    print("Login successful! Welcome.")
else:
    print("Login failed. Invalid username or password.")
# Out:
# Enter your username:  admin
# Enter your password:  password123
# Login successful! Welcome.

# %% [markdown]
# # Question 26

# %%
word = input("Enter a word: ")
character = input("Enter a character to check: ")

if character in word:
  print("The character is in the word.")

if character not in word:
  print("The character is not in the word.")
# Out:
# Enter a word:  letter
# Enter a character to check:  e
# The character is in the word.

# %% [markdown]
# # Question 27

# %%
email= "mr1517026@gmail.com"

"@" in email
# Out:
# True

# %% [markdown]
# # Question 28

# %%
sentence = input("Enter a sentence: ")

if "python" in sentence:
  print("Yes, the word 'python' exists in the sentence.")
else:
  print("No, the word 'python' exists not in the sentence.")
# Out:
# Enter a sentence:  I used a python programming language
# Yes, the word 'python' exists in the sentence.
